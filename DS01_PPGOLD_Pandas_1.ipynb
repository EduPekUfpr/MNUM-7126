# %% [markdown]
# <p style ="text-align:center">
#     <img src="http://epecora.com.br/DataFiles/PPGOLD_logo.png" width="300" alt="PPGOLD Data Science: INTRO"  />
# </p>
#
# # Aula 02: Data Science 1
# ## PANDAS

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# # Criando uma Series a partir de uma lista

# %%
# Criando uma Series a partir de uma lista
s = pd.Series([10, 20, 30, 40, 50, 60])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
frutas = ["Banana","Maçã","Goiaba","Melão","Mamão","Acerola"]

# %%
f = pd.Series(frutas)
f
# Out:
# 0     Banana
# 1       Maçã
# 2     Goiaba
# 3      Melão
# 4      Mamão
# 5    Acerola
# dtype: object

# %% [markdown]
# # Criando um DATA FRAME a partir das séries

# %%
df_frutas = pd.concat([f,s], axis = 1)
df_frutas
# Out:
#          0   1
# 0   Banana  10
# 1     Maçã  20
# 2   Goiaba  30
# 3    Melão  40
# 4    Mamão  50
# 5  Acerola  60

# %% [markdown]
# # Criando um DataFrame a partir de um dicionário

# %%
# Criando um DataFrame a partir de um dicionário
data = {'Nome': ['Alice', 'Bob', 'Charlie', 'David'],
        'Idade': [25, 30, 35, 40],
        'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Curitiba']}
data
# Out:
# {'Nome': ['Alice', 'Bob', 'Charlie', 'David'],
#  'Idade': [25, 30, 35, 40],
#  'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Curitiba']}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#       Nome  Idade          Cidade
# 0    Alice     25       São Paulo
# 1      Bob     30  Rio de Janeiro
# 2  Charlie     35  Belo Horizonte
# 3    David     40        Curitiba

# %% [markdown]
# # Lendo dads de um CSV

# %%
df_workers = pd.read_csv("https://raw.githubusercontent.com/EduPekUfpr/DS01_PPGOLD/main/dados.csv")
df_workers.head()
# Out:
#    ID   Nome  Idade  Salário
# 0   1  Alice     25     5000
# 1   2    Bob     30     6000
# 2   3  Carol     35     7000
# 3   4  David     40     8000
# 4   5  Emily     45     9000

# %%
df_workers.tail()
# Out:
#    ID   Nome  Idade  Salário
# 0   1  Alice     25     5000
# 1   2    Bob     30     6000
# 2   3  Carol     35     7000
# 3   4  David     40     8000
# 4   5  Emily     45     9000

# %%
df_workers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5 non-null      int64
#  1   Nome     5 non-null      object
#  2   Idade    5 non-null      int64
#  3   Salário  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 288.0+ bytes

# %% [markdown]
# ## Visualizando e inspecionando um DataFrame

# %%
# Carregando dados de um arquivo CSV
df = pd.read_csv("https://raw.githubusercontent.com/EduPekUfpr/DS01_PPGOLD/main/dados.csv")

# Visualizando as primeiras linhas do DataFrame
print(df.head())
# Out:
#    ID   Nome  Idade  Salário
# 0   1  Alice     25     5000
# 1   2    Bob     30     6000
# 2   3  Carol     35     7000
# 3   4  David     40     8000
# 4   5  Emily     45     9000

# %%
# Visualizando as informações básicas do DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5 non-null      int64
#  1   Nome     5 non-null      object
#  2   Idade    5 non-null      int64
#  3   Salário  5 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 288.0+ bytes
# None

# %%
# Visualizando estatísticas descritivas do DataFrame
print(df.describe())
# Out:
#              ID      Idade     Salário
# count  5.000000   5.000000     5.00000
# mean   3.000000  35.000000  7000.00000
# std    1.581139   7.905694  1581.13883
# min    1.000000  25.000000  5000.00000
# 25%    2.000000  30.000000  6000.00000
# 50%    3.000000  35.000000  7000.00000
# 75%    4.000000  40.000000  8000.00000
# max    5.000000  45.000000  9000.00000

# %%
# Verificando as colunas presentes no DataFrame
print(df.columns)
# Out:
# Index(['ID', 'Nome', 'Idade', 'Salário'], dtype='object')

# %%
# Verificando o índice do DataFrame
print(df.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %% [markdown]
# ## Indexação e Seleção de Dados

# %%
# Selecionando uma linha pelo rótulo
print(df.loc[0])
# Out:
# ID             1
# Nome       Alice
# Idade         25
# Salário     5000
# Name: 0, dtype: object

# %%
# Selecionando várias linhas e colunas pelo rótulo
print(df.loc[0:5, ['Nome', 'Idade']])
# Out:
#     Nome  Idade
# 0  Alice     25
# 1    Bob     30
# 2  Carol     35
# 3  David     40
# 4  Emily     45

# %%
# Selecionando linhas com base em uma condição
print(df.loc[df['Idade'] > 30])
# Out:
#    ID   Nome  Idade  Salário
# 2   3  Carol     35     7000
# 3   4  David     40     8000
# 4   5  Emily     45     9000

# %%
# Selecionando uma linha pela posição
print(df.iloc[0])
# Out:
# ID             1
# Nome       Alice
# Idade         25
# Salário     5000
# Name: 0, dtype: object

# %%
# Selecionando várias linhas e colunas pela posição
print(df.iloc[0:5, 0:2])
# Out:
#    ID   Nome
# 0   1  Alice
# 1   2    Bob
# 2   3  Carol
# 3   4  David
# 4   5  Emily

# %% [markdown]
# ## Identificar e Tratar Valores Ausentes

# %%
# Exemplo de DataFrame com valores ausentes
data = {'A': [1, 2, None, 4, 5],
        'B': [1, None, 3.5, None, 5.7],
        'C': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)
df.head()
# Out:
#      A    B  C
# 0  1.0  1.0  1
# 1  2.0  NaN  2
# 2  NaN  3.5  3
# 3  4.0  NaN  4
# 4  5.0  5.7  5

# %%
# Verificando valores ausentes por coluna
print(df.isna().sum())  # print(df.isnull().sum())
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %% [markdown]
# # Existem várias maneiras de tratar valores ausentes, algumas delas são:
#
# 1. Remover linhas ou colunas com valores ausentes:

# %%
# Removendo linhas com valores ausentes
df_clean_rows = df.dropna()
df_clean_rows
# Out:
#      A    B  C
# 0  1.0  1.0  1
# 4  5.0  5.7  5

# %%
# Removendo colunas com valores ausentes
df_clean_cols = df.dropna(axis=1)
df_clean_cols
# Out:
#    C
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# 2. Preencher valores ausentes com um valor específico:

# %%
# Preenchendo valores ausentes com zero
df_filled_zero = df.fillna(0)
df_filled_zero
# Out:
#      A    B  C
# 0  1.0  1.0  1
# 1  2.0  0.0  2
# 2  0.0  3.5  3
# 3  4.0  0.0  4
# 4  5.0  5.7  5

# %%
# Preenchendo valores ausentes com a média da coluna
df_filled_mean = df.fillna(df.mean())
df_filled_mean
# Out:
#      A    B  C
# 0  1.0  1.0  1
# 1  2.0  3.4  2
# 2  3.0  3.5  3
# 3  4.0  3.4  4
# 4  5.0  5.7  5

# %% [markdown]
# 3. Interpolar valores ausentes:

# %%
# Interpolando valores ausentes linearmente
df_interpolated = df.interpolate()
df_interpolated
# Out:
#      A     B  C
# 0  1.0  1.00  1
# 1  2.0  2.25  2
# 2  3.0  3.50  3
# 3  4.0  4.60  4
# 4  5.0  5.70  5

# %%
df_interpolated_grau2 = df.interpolate(method='polynomial', order=2)
df_interpolated_grau2
# Out:
#      A       B  C
# 0  1.0  1.0000  1
# 1  2.0  2.2875  2
# 2  3.0  3.5000  3
# 3  4.0  4.6375  4
# 4  5.0  5.7000  5

# %% [markdown]
# ## Autores
#
# <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pecora</a>
#
# ## Log de modificações
#
# | Data | Versão | Modificado por | Descrição |
# | -----------| ------- | ---------- | ---------------------------------- |
# | 04-03-2023       | 1.0     | Eduardo Pecora    | Inicial               |
