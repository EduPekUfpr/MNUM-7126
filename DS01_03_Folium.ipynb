# %% [markdown]
# <left>
#     <img src="http://epecora.com.br/DataFiles/PPGOLD_PPGMNE.png" width="800" alt="PPGOLD Data Science: INTRO"  />
# </left>
#
# # *Python - Aula 05*
#
# # Mapas - Folium

# %%
import pandas as pd
import folium

# %%
city = pd.read_csv("cities.csv")

# %%
city.tail()
# Out:
#                      city state   city_lat   city_lon  \
# 149      UNIAO DA VITORIA    PR -26.228596 -51.086980
# 150    VERA CRUZ DO OESTE    PR -25.058614 -53.878565
# 151         VILA SAO JOAO    RS -29.699890 -53.845836
# 152  VITORIA DA CONQUISTA    BA -14.856749 -40.841480
# 153              XINGUARA    PA  -7.099851 -49.941663
#
#                          city_coord
# 149          -26.228596,-51.0869796
# 150          -25.058614,-53.8785648
# 151  -29.6998896,-53.84583607326824
# 152         -14.8567487,-40.8414804
# 153          -7.0998514,-49.9416632

# %%
city.shape
# Out:
# (154, 5)

# %%
latO = city.loc[0].at["city_lat"]
lonO = city.loc[0].at["city_lon"]
nameO = city.loc[0].at["city"]

print(nameO)

m = folium.Map(location=[city.loc[0].at["city_lat"], city.loc[0].at["city_lon"]])

#plot Origin
folium.Marker(
    location=[latO, lonO],
    popup=nameO,
    icon=folium.Icon(color="blue"),
            ).add_to(m)

# Just to zoom the maps' bounds
m.fit_bounds(m.get_bounds())

#plot map
m
# Out:
# AGRO CAFEEIRA
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5081181b60ffd0a86181af8e0d4c3289 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5081181b60ffd0a86181af8e0d4c3289&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5081181b60ffd0a86181af8e0d4c3289 = L.map(
#                 &quot;map_5081181b60ffd0a86181af8e0d4c3289&quot;,
#                 {
#                     center: [-25.1943862, -53.9433081],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51372e1549c907fc44910ec32372faf3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_51372e1549c907fc44910ec32372faf3.addTo(map_5081181b60ffd0a86181af8e0d4c3289);
#
#
#             var marker_a76b235fcefbb709356015f7fa1e2d49 = L.marker(
#                 [-25.1943862, -53.9433081],
#                 {}
#             ).addTo(map_5081181b60ffd0a86181af8e0d4c3289);
#
#
#             var icon_23639deba03a4c0d26fbc57cb70f16d4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a76b235fcefbb709356015f7fa1e2d49.setIcon(icon_23639deba03a4c0d26fbc57cb70f16d4);
#
#
#         var popup_f5d02f77c88e1a8ede78672f7ac1eea2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf06115e41765e54fdd90954577d5896 = $(`&lt;div id=&quot;html_cf06115e41765e54fdd90954577d5896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AGRO CAFEEIRA&lt;/div&gt;`)[0];
#                 popup_f5d02f77c88e1a8ede78672f7ac1eea2.setContent(html_cf06115e41765e54fdd90954577d5896);
#
#
#
#         marker_a76b235fcefbb709356015f7fa1e2d49.bindPopup(popup_f5d02f77c88e1a8ede78672f7ac1eea2)
#         ;
#
#
#
#
#             map_5081181b60ffd0a86181af8e0d4c3289.fitBounds(
#                 [[-25.1943862, -53.9433081], [-25.1943862, -53.9433081]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
latO = city.loc[0].at["city_lat"]
lonO = city.loc[0].at["city_lon"]
nameO = city.loc[0].at["city"]

m = folium.Map(location=[city.loc[0].at["city_lat"], city.loc[0].at["city_lon"]])

#plot city
for i in range(city.shape[0]):
    latO = city.loc[i].at["city_lat"]
    lonO = city.loc[i].at["city_lon"]
    nameO = city.loc[i].at["city"]

    folium.Marker(
        location=[latO, lonO],
        popup=nameO,
        icon=folium.Icon(color="blue"),
                ).add_to(m)

# Just to zoom the maps' bounds
m.fit_bounds(m.get_bounds())

#plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70469c66678b09d7bc5488188f89f93f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70469c66678b09d7bc5488188f89f93f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70469c66678b09d7bc5488188f89f93f = L.map(
#                 &quot;map_70469c66678b09d7bc5488188f89f93f&quot;,
#                 {
#                     center: [-25.1943862, -53.9433081],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c07f34e23ae241334f4d810d41c488e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c07f34e23ae241334f4d810d41c488e8.addTo(map_70469c66678b09d7bc5488188f89f93f);
#
#
#             var marker_77692bfc0079f513959c1e4f0d6b93c9 = L.marker(
#                 [-25.1943862, -53.9433081],
#                 {}
#             ).addTo(map_70469c66678b09d7bc5488188f89f93f);
#
#
#             var icon_58cb6d15cb9058ddf41fb4347e5c37a6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_77692bfc0079f513959c1e4f0d6b93c9.setIcon(icon_58cb6d15cb9058ddf41fb4347e5c37a6);
#
#
#         var popup_918716543f178990587f892ec0c0638f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d025889a2b57901ade22359ae84b983 = $(`&lt;div id=&quot;html_2d025889a2b57901ade22359ae84b983&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AGRO CAFEEIRA&lt;/div&gt;`)[0];
#                 popup_918716543f178990587f892ec0c0638f.setContent(html_2d025889a2b57901ade22359ae84b983);
#
#
#
#         marker_77692bfc0079f513959c1e4f0d6b93c9.bindPopup(popup_918716543f178990587f892ec0c0638f)
#         ;
#
#
#
#
#             var marker_3354fcc028e1115ade3d9274740a6469 = L.marker(
#                 [-24.7416689, -50.5404834],
#                 {}
#             ).addTo(map_70469c66678b09d7bc5488188f89f93f);
#
#
#             var icon_1019b7fbc7287f11b1ee52de781c7eab = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3354fcc028e1115ade3d9274740a6469.setIcon(icon_1019b7fbc7287f11b1ee52de781c7eab);
#
#
#         var popup_558917e336e4d518a213582af5f22747 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e003bc7905324f83b68842feb6bf19e6 = $(`&lt;div id=&quot;html_e003bc7905324f83b68842feb6bf19e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ALTO DO AMPARO&lt;/div&gt;`)[0];
#                 popup_558917e336e4d518a213582af5f22747.setContent(html_e003bc7905324f83b68842feb6bf19e6);
#
#
#
#         marker_3354fcc028e1115ade3d9274740a6469.bindPopup(popup_558917e336e4d518a213582af5f22747)
#         ;
#
#
#
#
#             var marker_3a23d6cf1eb8a48c25b83899f70907be = L.marker(
#                 [-22.70111, -46.76444],
#                 {}
#             ).addTo(map_70469c66678b09d7bc5488188f89f93f);
#
#
#             var icon_41d8ef1813df1116a5cf15861e45ef17 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3a23d6cf1eb8a48c25b83899f70907be.setIcon(icon_41d8ef1813df1116a5cf15861e45ef17);
#
#
#         var popup_3b20b34e8ce86041a555bd56cfee483f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_856f7db667b2da6e63edacef4b1294a7 = $(`&lt;div id=&quot;html_856f7db667b2da6e63edacef4b1294a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AMPARO&lt;/div&gt;`)[0];
#                 popup_3b20b34e8ce86041a555bd56cfee483f.setContent(html_856f7db667b2da6e63edacef4b1294a7);
#
#
#
#         marker_3a23d6cf1eb8a48c25b83899f70907be.bindPopup(popup_3b20b34e8ce86041a555bd56cfee483f)
#         ;
#
#
#
#
#             var marker_3d9300d3d493d683852b11192c6dd3ae = L.marker(
#                 [-25.9168712, -53.4742414],
#                 {}
#             ).addTo(map_70469c66678b09d7bc5488188f89f93f);
#
#
#             var icon_77b88614d0bf6195f349d0a18b5541a7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &

# %%
city["state"].unique()
# Out:
# array(['PR', 'SP', 'SC', 'RS', 'BA', 'PA', 'DF', 'MS', 'PE', 'MT', 'CE',
#        'GO', 'TO', 'PB', 'AL', 'MG', 'RN', 'PI'], dtype=object)

# %%
city["state"]=="SP"
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 149    False
# 150    False
# 151    False
# 152    False
# 153    False
# Name: state, Length: 154, dtype: bool

# %%
citySP = city[city["state"]=="SP"]
print(citySP.head())


citySP.reset_index(inplace=True, drop = True)
citySP.head()
# Out:
#                  city state   city_lat   city_lon               city_coord
# 2              AMPARO    SP -22.701110 -46.764440      -22.70111,-46.76444
# 15  BRAGANCA PAULISTA    SP -22.952023 -46.541859  -22.9520235,-46.5418586
# 20             CAJATI    SP -24.727238 -48.107791  -24.7272376,-48.1077914
# 21           CAMPINAS    SP -22.905560 -47.060830      -22.90556,-47.06083
# 56             IGUAPE    SP -24.704269 -47.556373  -24.7042692,-47.5563733
#                 city state   city_lat   city_lon               city_coord
# 0             AMPARO    SP -22.701110 -46.764440      -22.70111,-46.76444
# 1  BRAGANCA PAULISTA    SP -22.952023 -46.541859  -22.9520235,-46.5418586
# 2             CAJATI    SP -24.727238 -48.107791  -24.7272376,-48.1077914
# 3           CAMPINAS    SP -22.905560 -47.060830      -22.90556,-47.06083
# 4             IGUAPE    SP -24.704269 -47.556373  -24.7042692,-47.5563733

# %%
latO = citySP.loc[0].at["city_lat"]
lonO = citySP.loc[0].at["city_lon"]
nameO = citySP.loc[0].at["city"]

m = folium.Map(location=[citySP.loc[0].at["city_lat"], citySP.loc[0].at["city_lon"]])

#plot Origin
for i in range(citySP.shape[0]):
    latO = citySP.loc[i].at["city_lat"]
    lonO = citySP.loc[i].at["city_lon"]
    nameO = citySP.loc[i].at["city"]

    folium.Marker(
        location=[latO, lonO],
        popup=nameO,
        icon=folium.Icon(color="blue"),
                ).add_to(m)

# Just to zoom the maps' bounds
m.fit_bounds(m.get_bounds())

#plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7174e2dc8f10851b4f7fad59203c318 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7174e2dc8f10851b4f7fad59203c318&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7174e2dc8f10851b4f7fad59203c318 = L.map(
#                 &quot;map_a7174e2dc8f10851b4f7fad59203c318&quot;,
#                 {
#                     center: [-22.70111, -46.76444],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c38366627f08f0e4d463198990898c11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c38366627f08f0e4d463198990898c11.addTo(map_a7174e2dc8f10851b4f7fad59203c318);
#
#
#             var marker_fe1e4e8c6814b9d0023df610163ba283 = L.marker(
#                 [-22.70111, -46.76444],
#                 {}
#             ).addTo(map_a7174e2dc8f10851b4f7fad59203c318);
#
#
#             var icon_6de6b1b279a849b6fc4940fb12ca2665 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe1e4e8c6814b9d0023df610163ba283.setIcon(icon_6de6b1b279a849b6fc4940fb12ca2665);
#
#
#         var popup_0f9a62205385db33bf1d5064d47cd966 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9c20eab566e3a77a8a25b122a51e8b2b = $(`&lt;div id=&quot;html_9c20eab566e3a77a8a25b122a51e8b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AMPARO&lt;/div&gt;`)[0];
#                 popup_0f9a62205385db33bf1d5064d47cd966.setContent(html_9c20eab566e3a77a8a25b122a51e8b2b);
#
#
#
#         marker_fe1e4e8c6814b9d0023df610163ba283.bindPopup(popup_0f9a62205385db33bf1d5064d47cd966)
#         ;
#
#
#
#
#             var marker_6ffcfaa66b0befaafad7edf2c2f8f23c = L.marker(
#                 [-22.9520235, -46.5418586],
#                 {}
#             ).addTo(map_a7174e2dc8f10851b4f7fad59203c318);
#
#
#             var icon_e55a816ff548fde7c220103bdee9b8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ffcfaa66b0befaafad7edf2c2f8f23c.setIcon(icon_e55a816ff548fde7c220103bdee9b8b3);
#
#
#         var popup_03d6f1acec081501029748cbf4763fe5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3e2e3def60bd6a12ef9415147f13116f = $(`&lt;div id=&quot;html_3e2e3def60bd6a12ef9415147f13116f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BRAGANCA PAULISTA&lt;/div&gt;`)[0];
#                 popup_03d6f1acec081501029748cbf4763fe5.setContent(html_3e2e3def60bd6a12ef9415147f13116f);
#
#
#
#         marker_6ffcfaa66b0befaafad7edf2c2f8f23c.bindPopup(popup_03d6f1acec081501029748cbf4763fe5)
#         ;
#
#
#
#
#             var marker_c4597f2dc377fad6aa485cb0aea78710 = L.marker(
#                 [-24.7272376, -48.1077914],
#                 {}
#             ).addTo(map_a7174e2dc8f10851b4f7fad59203c318);
#
#
#             var icon_6e53ff6a5a9840137be88647ffae7c2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c4597f2dc377fad6aa485cb0aea78710.setIcon(icon_6e53ff6a5a9840137be88647ffae7c2e);
#
#
#         var popup_acd3c551f781fb20bf4fa5ad99b52680 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c21ae6684a607abcc2bc3ddb6d6bad9 = $(`&lt;div id=&quot;html_5c21ae6684a607abcc2bc3ddb6d6bad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAJATI&lt;/div&gt;`)[0];
#                 popup_acd3c551f781fb20bf4fa5ad99b52680.setContent(html_5c21ae6684a607abcc2bc3ddb6d6bad9);
#
#
#
#         marker_c4597f2dc377fad6aa485cb0aea78710.bindPopup(popup_acd3c551f781fb20bf4fa5ad99b52680)
#         ;
#
#
#
#
#             var marker_36a99cea7bc00b37a6c2f63d7b1c3bc6 = L.marker(
#                 [-22.90556, -47.06083],
#                 {}
#             ).addTo(map_a7174e2dc8f10851b4f7fad59203c318);
#
#
#             var icon_d23a1d7d3f00a181de1fa06d1b59e3cf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerC

# %%
cityRS = city[city["state"]=="RS"]
cityRS.reset_index(inplace=True, drop = True )
cityRS.head()
# Out:
#              city state   city_lat   city_lon               city_coord
# 0            BAGE    RS -31.331426 -54.106281  -31.3314264,-54.1062808
# 1  CAPAO DA CANOA    RS -29.750828 -50.021073  -29.7508278,-50.0210729
# 2            IJUI    RS -28.387873 -53.920169  -28.3878734,-53.9201692
# 3            IMBE    RS -29.976649 -50.127871  -29.9766491,-50.1278714
# 4          OSORIO    RS -29.889073 -50.274050  -29.8890733,-50.2740498

# %%
latO = cityRS.loc[0].at["city_lat"]
lonO = cityRS.loc[0].at["city_lon"]
nameO = cityRS.loc[0].at["city"]

m = folium.Map(location=[cityRS.loc[0].at["city_lat"], cityRS.loc[0].at["city_lon"]])

#plot Origin
for i in range(cityRS.shape[0]):
    latO = cityRS.loc[i].at["city_lat"]
    lonO = cityRS.loc[i].at["city_lon"]
    nameO = cityRS.loc[i].at["city"]

    folium.Marker(
        location=[latO, lonO],
        popup=nameO,
        icon=folium.Icon(color="green"),
                ).add_to(m)

# Just to zoom the maps' bounds
m.fit_bounds(m.get_bounds())

#plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_beb688b497aefff77e3759c20aa66844 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_beb688b497aefff77e3759c20aa66844&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_beb688b497aefff77e3759c20aa66844 = L.map(
#                 &quot;map_beb688b497aefff77e3759c20aa66844&quot;,
#                 {
#                     center: [-31.3314264, -54.1062808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3320a7d4998ce397156435fa96cc0f23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3320a7d4998ce397156435fa96cc0f23.addTo(map_beb688b497aefff77e3759c20aa66844);
#
#
#             var marker_8c0fb80e1e8e66a4e4ab712c9b4e91f4 = L.marker(
#                 [-31.3314264, -54.1062808],
#                 {}
#             ).addTo(map_beb688b497aefff77e3759c20aa66844);
#
#
#             var icon_c073eccdbfa0eeb12e9f7ee3740edbcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8c0fb80e1e8e66a4e4ab712c9b4e91f4.setIcon(icon_c073eccdbfa0eeb12e9f7ee3740edbcf);
#
#
#         var popup_90f9cf6dcd92eff85581424e9896b582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8d56d44e1f51e32bdc1dbeeff98b79c = $(`&lt;div id=&quot;html_e8d56d44e1f51e32bdc1dbeeff98b79c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAGE&lt;/div&gt;`)[0];
#                 popup_90f9cf6dcd92eff85581424e9896b582.setContent(html_e8d56d44e1f51e32bdc1dbeeff98b79c);
#
#
#
#         marker_8c0fb80e1e8e66a4e4ab712c9b4e91f4.bindPopup(popup_90f9cf6dcd92eff85581424e9896b582)
#         ;
#
#
#
#
#             var marker_6d21bba8d9ed92b9e664d1cc1f194b7c = L.marker(
#                 [-29.7508278, -50.0210729],
#                 {}
#             ).addTo(map_beb688b497aefff77e3759c20aa66844);
#
#
#             var icon_c9818478541eaf2ca63140ec3e38e1ae = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6d21bba8d9ed92b9e664d1cc1f194b7c.setIcon(icon_c9818478541eaf2ca63140ec3e38e1ae);
#
#
#         var popup_b35fc4a3f44fcbba0cd5c98d7e81677f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b9426f0b4cb7a7b60e5b364109af0fc8 = $(`&lt;div id=&quot;html_b9426f0b4cb7a7b60e5b364109af0fc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAPAO DA CANOA&lt;/div&gt;`)[0];
#                 popup_b35fc4a3f44fcbba0cd5c98d7e81677f.setContent(html_b9426f0b4cb7a7b60e5b364109af0fc8);
#
#
#
#         marker_6d21bba8d9ed92b9e664d1cc1f194b7c.bindPopup(popup_b35fc4a3f44fcbba0cd5c98d7e81677f)
#         ;
#
#
#
#
#             var marker_91e52b5af925c4ced6c32dffa916e005 = L.marker(
#                 [-28.3878734, -53.9201692],
#                 {}
#             ).addTo(map_beb688b497aefff77e3759c20aa66844);
#
#
#             var icon_d47e6cc5ae6ba503cadf780d72264bad = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91e52b5af925c4ced6c32dffa916e005.setIcon(icon_d47e6cc5ae6ba503cadf780d72264bad);
#
#
#         var popup_47b0483999228b4dfb7a53ed96f5d67f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_558563b44999584fb65e48ec0de13ee1 = $(`&lt;div id=&quot;html_558563b44999584fb65e48ec0de13ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IJUI&lt;/div&gt;`)[0];
#                 popup_47b0483999228b4dfb7a53ed96f5d67f.setContent(html_558563b44999584fb65e48ec0de13ee1);
#
#
#
#         marker_91e52b5af925c4ced6c32dffa916e005.bindPopup(popup_47b0483999228b4dfb7a53ed96f5d67f)
#         ;
#
#
#
#
#             var marker_74ebe5c38192a30a29174fc4a47b3b33 = L.marker(
#                 [-29.9766491, -50.1278714],
#                 {}
#             ).addTo(map_beb688b497aefff77e3759c20aa66844);
#
#
#             var icon_a7ac0a718c7e5f5d0d194011a07c2826 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot

# %%
cityRS
# Out:
#              city state   city_lat   city_lon                      city_coord
# 0            BAGE    RS -31.331426 -54.106281         -31.3314264,-54.1062808
# 1  CAPAO DA CANOA    RS -29.750828 -50.021073         -29.7508278,-50.0210729
# 2            IJUI    RS -28.387873 -53.920169         -28.3878734,-53.9201692
# 3            IMBE    RS -29.976649 -50.127871         -29.9766491,-50.1278714
# 4          OSORIO    RS -29.889073 -50.274050         -29.8890733,-50.2740498
# 5     PASSO FUNDO    RS -28.255060 -52.396661         -28.2550598,-52.3966606
# 6    PORTO ALEGRE    RS -30.032500 -51.230377         -30.0324999,-51.2303767
# 7          TORRES    RS -29.337366 -49.729965         -29.3373663,-49.7299648
# 8       TRAMANDAI    RS -29.985534 -50.131608         -29.9855339,-50.1316076
# 9   VILA SAO JOAO    RS -29.699890 -53.845836  -29.6998896,-53.84583607326824

# %%
latO = cityRS.loc[0].at["city_lat"]
lonO = cityRS.loc[0].at["city_lon"]
nameO = cityRS.loc[0].at["city"]

latRef = cityRS.loc[6].at["city_lat"]
lonRef = cityRS.loc[6].at["city_lon"]

m = folium.Map(location=[cityRS.loc[0].at["city_lat"], cityRS.loc[0].at["city_lon"]])

#plot Origin
for i in range(cityRS.shape[0]):
    latO = cityRS.loc[i].at["city_lat"]
    lonO = cityRS.loc[i].at["city_lon"]
    nameO = cityRS.loc[i].at["city"]

    folium.Marker(
        location=[latO, lonO],
        popup=nameO,
        icon=folium.Icon(color="green"),
                ).add_to(m)

    #plot lines
    coords = [[latO,lonO],[latRef,lonRef]]
    folium.PolyLine(coords, color="green").add_to(m) 

# Just to zoom the maps' bounds
m.fit_bounds(m.get_bounds())

#plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f2e41bf246bab38e6071bcdedfc527b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f2e41bf246bab38e6071bcdedfc527b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f2e41bf246bab38e6071bcdedfc527b = L.map(
#                 &quot;map_8f2e41bf246bab38e6071bcdedfc527b&quot;,
#                 {
#                     center: [-31.3314264, -54.1062808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8127f7e31b73cc0a63df4a2b49aa9933 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8127f7e31b73cc0a63df4a2b49aa9933.addTo(map_8f2e41bf246bab38e6071bcdedfc527b);
#
#
#             var marker_2917324d233d28ba3a415f9ddbca1adc = L.marker(
#                 [-31.3314264, -54.1062808],
#                 {}
#             ).addTo(map_8f2e41bf246bab38e6071bcdedfc527b);
#
#
#             var icon_5b2a900dda7afeaa1ec82c3d40d6fa36 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2917324d233d28ba3a415f9ddbca1adc.setIcon(icon_5b2a900dda7afeaa1ec82c3d40d6fa36);
#
#
#         var popup_a6bd9acb33a2529d2524c2a193cd3963 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8e6716168962130825a8a44454292c8 = $(`&lt;div id=&quot;html_e8e6716168962130825a8a44454292c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAGE&lt;/div&gt;`)[0];
#                 popup_a6bd9acb33a2529d2524c2a193cd3963.setContent(html_e8e6716168962130825a8a44454292c8);
#
#
#
#         marker_2917324d233d28ba3a415f9ddbca1adc.bindPopup(popup_a6bd9acb33a2529d2524c2a193cd3963)
#         ;
#
#
#
#
#             var poly_line_88d86e917f364cba227bf4b7fa43147e = L.polyline(
#                 [[-31.3314264, -54.1062808], [-30.0324999, -51.2303767]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f2e41bf246bab38e6071bcdedfc527b);
#
#
#             var marker_e75e12ea12d21afd087e7a6806c29b93 = L.marker(
#                 [-29.7508278, -50.0210729],
#                 {}
#             ).addTo(map_8f2e41bf246bab38e6071bcdedfc527b);
#
#
#             var icon_a2cb0a561540a049f9449cf968ca965c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e75e12ea12d21afd087e7a6806c29b93.setIcon(icon_a2cb0a561540a049f9449cf968ca965c);
#
#
#         var popup_d3ee2860d20e25c2fcd612cb866e8fd4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_373397fc63dfa76511e0e6b0ced04506 = $(`&lt;div id=&quot;html_373397fc63dfa76511e0e6b0ced04506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAPAO DA CANOA&lt;/div&gt;`)[0];
#                 popup_d3ee2860d20e25c2fcd612cb866e8fd4.setContent(html_373397fc63dfa76511e0e6b0ced04506);
#
#
#
#         marker_e75e12ea12d21afd087e7a6806c29b93.bindPopup(popup_d3ee2860d20e25c2fcd612cb866e8fd4)
#         ;
#
#
#
#
#             var poly_line_642772571352032d311b71c3740d152c = L.polyline(
#                 [[-29.7508278, -50.0210729], [-30.0324999, -51.2303767]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8f2e41bf246bab38e6071bcdedfc527b);
#
#
#             var marker_0072da257e22045840e42e0173f36abd = L.marker(
#                 [-28.3878734, -53.9201692],
#                 {}
#             ).addTo(map_8f2e41bf246bab38e6071bcdedfc527b);
#
#
#             va

# %%
m = folium.Map(location=[45.372, -121.6972], zoom_start=12, tiles="Cartodb Positron")


latO = cityRS.loc[0].at["city_lat"]
lonO = cityRS.loc[0].at["city_lon"]
nameO = cityRS.loc[0].at["city"]

latRef = cityRS.loc[6].at["city_lat"]
lonRef = cityRS.loc[6].at["city_lon"]

m = folium.Map(location=[cityRS.loc[0].at["city_lat"], cityRS.loc[0].at["city_lon"]], tiles="Cartodb Positron")

#plot Origin
for i in range(cityRS.shape[0]):
    latO = cityRS.loc[i].at["city_lat"]
    lonO = cityRS.loc[i].at["city_lon"]
    nameO = cityRS.loc[i].at["city"]

    folium.Marker(
        location=[latO, lonO],
        popup=nameO,
        icon=folium.Icon(color="green"),
                ).add_to(m)

    #plot lines
    coords = [[latO,lonO],[latRef,lonRef]]
    folium.PolyLine(coords, color="green").add_to(m) 

# Just to zoom the maps' bounds
m.fit_bounds(m.get_bounds())

#plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8a30192ebb3c35d47a987c838874fcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8a30192ebb3c35d47a987c838874fcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8a30192ebb3c35d47a987c838874fcb = L.map(
#                 &quot;map_c8a30192ebb3c35d47a987c838874fcb&quot;,
#                 {
#                     center: [-31.3314264, -54.1062808],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f08ff3be3a529e90c7856301adbae87b = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f08ff3be3a529e90c7856301adbae87b.addTo(map_c8a30192ebb3c35d47a987c838874fcb);
#
#
#             var marker_c0832b6e601585793d10e212161806ab = L.marker(
#                 [-31.3314264, -54.1062808],
#                 {}
#             ).addTo(map_c8a30192ebb3c35d47a987c838874fcb);
#
#
#             var icon_6010986159e8063aa0bc29eb27d5fb82 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c0832b6e601585793d10e212161806ab.setIcon(icon_6010986159e8063aa0bc29eb27d5fb82);
#
#
#         var popup_faf96bff272d8cb8bf73e24928989caa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_300b6279c23cd53d9696d76123e36f13 = $(`&lt;div id=&quot;html_300b6279c23cd53d9696d76123e36f13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BAGE&lt;/div&gt;`)[0];
#                 popup_faf96bff272d8cb8bf73e24928989caa.setContent(html_300b6279c23cd53d9696d76123e36f13);
#
#
#
#         marker_c0832b6e601585793d10e212161806ab.bindPopup(popup_faf96bff272d8cb8bf73e24928989caa)
#         ;
#
#
#
#
#             var poly_line_146fcd11448b0a3b97309bd22b516cb7 = L.polyline(
#                 [[-31.3314264, -54.1062808], [-30.0324999, -51.2303767]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c8a30192ebb3c35d47a987c838874fcb);
#
#
#             var marker_e4e32c4bcde5b3de7374c45db97f3f16 = L.marker(
#                 [-29.7508278, -50.0210729],
#                 {}
#             ).addTo(map_c8a30192ebb3c35d47a987c838874fcb);
#
#
#             var icon_c83446909b8ba0a2a8e2dd3055b4b500 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4e32c4bcde5b3de7374c45db97f3f16.setIcon(icon_c83446909b8ba0a2a8e2dd3055b4b500);
#
#
#         var popup_c8f2cd01b164caf7656c4665c10a310b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d429508ced937aa5c80c56bfd140e36f = $(`&lt;div id=&quot;html_d429508ced937aa5c80c56bfd140e36f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CAPAO DA CANOA&lt;/div&gt;`)[0];
#                 popup_c8f2cd01b164caf7656c4665c10a310b.setContent(html_d429508ced937aa5c80c56bfd140e36f);
#
#
#
#         marker_e4e32c4bcde5b3de7374c45db97f3f16.bindPopup(popup_c8f2cd01b164caf7656c4665c10a310b)
#         ;
#
#
#
#
#             var poly_line_37ac93fb24b703bd6410e2d916021984 = L.polyline(
#                 [[-29.7508278, -50.0210729], [-30.0324999, -51.2303767]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c8a30192ebb3c35d47a987c838874fcb);
#
#
#             var marker_bdbd0ff6acd4a3274b34870c657ca016 = L.marker(
#                 [-28.3878734, -53.9201

# %% [markdown]
# ## Choropleth
#
# Usa o polígono e preenche com algum dado

# %%
url = ("https://raw.githubusercontent.com/python-visualization/folium/main/examples/data")

state_geo = f"{url}/us-states.json"
state_unemployment = f"{url}/US_Unemployment_Oct2012.csv"
state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name="choropleth",
    data=state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)",
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12724f5fd635c775639e9a51f09dccdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12724f5fd635c775639e9a51f09dccdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12724f5fd635c775639e9a51f09dccdc = L.map(
#                 &quot;map_12724f5fd635c775639e9a51f09dccdc&quot;,
#                 {
#                     center: [48.0, -102.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93195f3f236ef8f1c773371769a840d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_93195f3f236ef8f1c773371769a840d0.addTo(map_12724f5fd635c775639e9a51f09dccdc);
#
#
#             var choropleth_ee37727a96b8990a73bb45c40205e9ae = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AK&quot;: case &quot;AR&quot;: case &quot;CO&quot;: case &quot;DE&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;NM&quot;: case &quot;OH&quot;: case &quot;TN&quot;: case &quot;WA&quot;: case &quot;WV&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AZ&quot;: case &quot;CT&quot;: case &quot;FL&quot;: case &quot;GA&quot;: case &quot;IL&quot;: case &quot;IN&quot;: case &quot;KY&quot;: case &quot;MI&quot;: case &quot;MS&quot;: case &quot;NY&quot;: case &quot;OR&quot;: case &quot;PA&quot;: case &quot;SC&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;: case &quot;NV&quot;: case &quot;NJ&quot;: case &quot;NC&quot;: case &quot;RI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;HI&quot;: case &quot;IA&quot;: case &quot;OK&quot;: case &quot;SD&quot;: case &quot;UT&quot;: case &quot;VT&quot;: case &quot;WY&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;ID&quot;: case &quot;KS&quot;: case &quot;LA&quot;: case &quot;MA&quot;: case &quot;MN&quot;: case &quot;MO&quot;: case &quot;MT&quot;: case &quot;NH&quot;: case &quot;TX&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724 = L.geoJson(null, {
#                 onEachFeature: geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724_onEachFeature,
#
#                 style: geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724_styler,
#         });
#
#         function geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724_add (data) {
#             geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724
#                 .addData(data);
#         }
#             geo_json_cdf76aab8e9a6f83d9ab9ea61a03e724_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-87.359296, 35.00118], [-85.606675, 34.984749], [-85.431413, 34.124869], [-85.184951, 32.859696], [-85.069935, 32.580372], [-84.960397, 32.421541], [-85.004212, 32.322956], [-84.889196, 32.262709], [-85.058981, 32.13674], [-85.053504, 32.01077], [-85.141136, 31.840985], [-85.042551, 31.539753], [-85.113751, 31.27686], [-85.004212, 31.003013], [-85.497137, 30.997536], [-87.600282, 30.997536], [-87.633143, 30.86609], [-87.408589, 30.674397], [-87.446927, 30.510088], [-87.37025, 30.427934], [-87.518128, 30.280057], [-87.655051, 30.247195], [-87.90699, 30.411504], [-87.934375, 30.657966], [-88.011052, 30.685351], [-88.10416, 30.499135], [-88.137022, 30.318396], [-88.394438, 30.367688], [-88.471115, 31.895754], [-88.241084, 33.796253], [-88.098683, 34.891641], [-88.202745, 34.995703], [-87.359296, 35.00118]]], &quot;type&qu

# %% [markdown]
# ## Georeferenciamento do Brasil

# %%
# fronteiras das cidades do brasil 
# https://github.com/tbrugz/geodata-br
# fronteiras dos estados brasileiros 
# https://gist.githubusercontent.com/ruliana/1ccaaab05ea113b0dff3b22be3b4d637/raw/196c0332d38cb935cfca227d28f7cecfa70b412e/br-states.json

br_state_geo = "https://gist.githubusercontent.com/ruliana/1ccaaab05ea113b0dff3b22be3b4d637/raw/196c0332d38cb935cfca227d28f7cecfa70b412e/br-states.json"

# %% [markdown]
# ## Full map of Brazil
#
# ### Several Layers
#
# Load the file “bcim_2016_21_11_2018.gpkg”. This file contains a series of relevant layers to create this type of plots.
# Where can I find this file? On IBGE website https://www.ibge.gov.br/
#
#
# #### After accessing the website, follow the steps below:
# * Página Principal
# * Geociências
# * Cartas e Mapas
# * Bases cartográficas contínuas
# * Bases cartográficas contínuas - Brasil

# %% [markdown]
# ## Rotas
#
# * a biblioteca ```Nominatim``` encontra as coordenadas com o nome da cidade e vice-e-versa.
# * O método ```osmnx.graph_from_point``` faz o dowload de todos os pontos em torno de uma coordenada e tranforma nu grafo. A distância é dada pelo atributo ```dist``` em metros. Vocês devem imaginar que se este atributo for muito grande a teremos muitos pontos, mas muitos mesmos.
# * O método ```networkx.shortest_path``` aplica o algoritmo de Djikstra (se pronuncia Dáistra) ao grafo gerado acima. então se tivermos muitos pontos a resolução irá demorar muito.

# %%
import osmnx as ox
import networkx as nx
from geopy.geocoders import Nominatim

# Initialize the geolocator
geolocator = Nominatim(user_agent="route_map")

# Get the coordinates for São José dos Pinhais
cwb_location = geolocator.geocode("Curitiba, PR, Brazil")
cwb_coords = (cwb_location.latitude, cwb_location.longitude)

# Get the coordinates for Curitiba
sjp_location = geolocator.geocode("São José dos Pinhais, PR, Brazil")
sjp_coords = (sjp_location.latitude, sjp_location.longitude)

# Download the road network graph around Curitiba
G = ox.graph_from_point(cwb_coords, dist=12000, network_type='drive')

# Get the nearest nodes to the start and end points
orig_node = ox.distance.nearest_nodes(G, cwb_coords[1], cwb_coords[0])
dest_node = ox.distance.nearest_nodes(G, sjp_coords[1], sjp_coords[0])

# Find the shortest path using Dijkstra's algorithm
route = nx.shortest_path(G, orig_node, dest_node, weight='length')

# Extract the latitude and longitude for the nodes in the route
route_points = [(G.nodes[node]['y'], G.nodes[node]['x']) for node in route]

# Create a Folium map centered at Curitiba
route_map = folium.Map(location=cwb_coords)

# Add the route to the map
folium.PolyLine(route_points, color='blue', weight=2.5, opacity=1).add_to(route_map)

# Add markers for New York City and Buffalo
folium.Marker(cwb_coords, popup='Curitiba').add_to(route_map)
folium.Marker(sjp_coords, popup='São José dos Pinhais').add_to(route_map)

# Correct the zoom
route_map.fit_bounds(route_map.get_bounds())

# Save the map to an HTML file
route_map.save("cwb_sjp_route.html")

# Show the map
route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d57c0962b19432e70fa7fe3588bf39e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d57c0962b19432e70fa7fe3588bf39e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d57c0962b19432e70fa7fe3588bf39e = L.map(
#                 &quot;map_8d57c0962b19432e70fa7fe3588bf39e&quot;,
#                 {
#                     center: [-25.4295963, -49.2712724],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b70acd38247cad3c6d974ef0a25a1af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1b70acd38247cad3c6d974ef0a25a1af.addTo(map_8d57c0962b19432e70fa7fe3588bf39e);
#
#
#             var poly_line_03c409de0604629e0f48686a76a395c1 = L.polyline(
#                 [[-25.42986, -49.2710341], [-25.4284073, -49.2710738], [-25.4280546, -49.2712694], [-25.428579, -49.2731567], [-25.4295079, -49.2726925], [-25.4301569, -49.2723626], [-25.4302992, -49.2724206], [-25.4305865, -49.2731462], [-25.4310958, -49.2729037], [-25.4325024, -49.272234], [-25.4328363, -49.2728219], [-25.433615, -49.2724374], [-25.4345269, -49.2720375], [-25.4358844, -49.2714077], [-25.4375175, -49.27065], [-25.4376296, -49.270598], [-25.4388465, -49.2700333], [-25.4389866, -49.2699683], [-25.4403822, -49.2693208], [-25.4404853, -49.2692729], [-25.4418827, -49.2686245], [-25.4419892, -49.2685751], [-25.443421, -49.2679108], [-25.4448476, -49.267247], [-25.4461747, -49.2666297], [-25.447518, -49.2660047], [-25.4486727, -49.2654676], [-25.4503917, -49.2646677], [-25.4515212, -49.2641395], [-25.4520974, -49.26387], [-25.4522123, -49.2638163], [-25.453123, -49.2633978], [-25.4541402, -49.2629146], [-25.454642, -49.2626768], [-25.4556477, -49.2622123], [-25.4567424, -49.2616915], [-25.4582533, -49.2609444], [-25.4592286, -49.260475], [-25.4601991, -49.259979], [-25.4611525, -49.259484], [-25.46216, -49.2589905], [-25.4630946, -49.2585209], [-25.4640166, -49.2580587], [-25.4649507, -49.2576107], [-25.4658887, -49.257152], [-25.4668942, -49.2566834], [-25.4670689, -49.2567773], [-25.4673363, -49.2573309], [-25.4674781, -49.2573857], [-25.4677961, -49.25718], [-25.4699666, -49.2550174], [-25.4703957, -49.2546313], [-25.4709316, -49.2540793], [-25.4723615, -49.2530871], [-25.4735196, -49.2525216], [-25.4746346, -49.251977], [-25.4757567, -49.2514292], [-25.4769073, -49.2508674], [-25.4780499, -49.25031], [-25.479175, -49.2497604], [-25.4803173, -49.2492027], [-25.4814702, -49.2486397], [-25.4832965, -49.2477479], [-25.4850207, -49.2469059], [-25.485137, -49.2468491], [-25.4869317, -49.2459712], [-25.487056, -49.2459104], [-25.4873954, -49.2457444], [-25.4888045, -49.2450551], [-25.4906439, -49.2441553], [-25.4924817, -49.2432563], [-25.4942941, -49.2423697], [-25.4960329, -49.2415166], [-25.4961789, -49.241445], [-25.4979736, -49.2405644], [-25.4998055, -49.2396656], [-25.5013419, -49.2389118], [-25.5016438, -49.2387636], [-25.5022785, -49.2373723], [-25.5030754, -49.2368642], [-25.5104384, -49.2332738], [-25.5122645, -49.2324125], [-25.5141178, -49.231489], [-25.5160237, -49.2307599], [-25.5163555, -49.231583], [-25.5181906, -49.2306883], [-25.5179247, -49.2300316], [-25.5192327, -49.2290108], [-25.521482, -49.227913], [-25.5219431, -49.227688], [-25.5272158, -49.221973], [-25.5281569, -49.2198404], [-25.5304998, -49.2149985], [-25.530743, -49.2144163], [-25.530885, -49.2140715], [-25.5316147, -49.2130606], [-25.5323643, -49.2121352], [-25.5331621, -49.211109], [-25.5334994, -49.2099857], [-25.5338075, -49.20896], [-25.5342318, -49.2075474]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_8d57c0962b19432e70fa7fe3588bf39e);
#
#
#             var marker_9130930e21cba516724ca2f369d22bb7 = L.marker(
#                 [-25.4295963, -49.2712724],
#                 {}
#             ).addTo(map_8d57c0962b19432e70fa7fe3588bf39e);
#
#
#         var popup_f154979b0a5433e53e2d0da0ebd11a52 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aed389dbf13abffc3d0c6eea082b0817 = $(`&lt;div id=&quot;html_aed389dbf13abffc3d0c6eea082b0817&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Curitiba&lt;/div&gt;`)[0];
#                 popup_f154979b0a5433e53e2d0da0ebd11a52.setContent(html_aed389dbf13abffc3d0c6eea082b0817);
#
#
#
#         marker_9130930e21cba5

# %% [markdown]
# ## References
#
# * https://python-visualization.github.io/folium/quickstart.html
# * https://nominatim.org
# * https://geopy.readthedocs.io/en/stable/#module-geopy.geocoders
# * https://osmnx.readthedocs.io/en/stable/user-reference.html
#
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2023-05-10  | 0.9  | <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pécora</a> |  Initial development |
# | 2024-05-28  | 1.0  | <a href="https://www.linkedin.com/in/eduardopecora/" target="_blank">Eduardo Pécora</a> |  Routes |
#
# <hr>
